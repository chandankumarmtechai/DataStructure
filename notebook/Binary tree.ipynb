# %% [markdown]
# <h1 style="color:blue"> Binary tree </h1>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='id1'></a>
# <h2 style="color:blue">Basic concepts</h2>
# <blockquote style="background:lightgreen; color:blue; font-size:5x">Binary tree is data structure concept.
#
# </blockquote>

# %% [markdown]
# <a id='intr'></a>
# <h2 style="color:blue"> Introduction </h2>
#
# [1. Binary Tree | Set 1 (Introduction)](#intr1) <br>
# [2. Binary Tree | Set 2 (Properties)](#intr2) <br>
# [3. Binary Tree | Set 3 (Types of Binary Tree)](#intr3) <br>
# [4. Handshaking Lemma and Interesting Tree Properties](#intr4) <br>
# [5. Enumeration of Binary Trees](#intr5) <br>
# [6. Insertion in a Binary Tree](#intr6) <br>
# [7. Deletion in a Binary Tree](#intr7) <br>
# [8. BFS vs DFS for Binary Tree](#intr8) <br>
# [9. Binary Tree (Array implementation)](#intr9) <br>
# [10. AVL with duplicate keys](#intr10) <br>
# [11. Applications of tree data structure](#intr11) <br>
# [12. Applications of Minimum Spanning Tree Problem](#intr12) <br>
# [13. Continuous Tree](#intr13) <br>
# [14. Foldable Binary Trees](#intr14) <br>
# [15. Expression Tree](#intr15) <br>
# [16. Evaluation of Expression Tree](#intr16) <br>
# [17. Symmetric Tree (Mirror Image of itself)](#intr17) <br>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='trv'></a>
# <h2 style="color:blue"> Traversals </h2>
#
# [1. Tree Traversals](#trv1)- <br>
# [2. Inorder Tree Traversal without Recursion](#trv2) <br>
# [3. Inorder Tree Traversal without recursion and without stack!](#trv3) <br>
# [4. Print Postorder traversal from given Inorder and Preorder traversals](#trv4) <br>
# [5. Find postorder traversal of BST from preorder traversal](#trv5) <br>
# [6. Find all possible binary trees with given Inorder Traversal](#trv6) <br>
# [7. Replace each node in binary tree with the sum of its inorder predecessor and successor](#trv7) <br>
# [8. Populate Inorder Successor for all nodes](#trv8) <br>
# [9. Inorder Successor of a node in Binary Tree](#trv9) <br>
# [10. Find n-th node of inorder traversal](#trv10) <br>
# [11. Find n-th node in Postorder traversal of a Binary Tree](#trv11) <br>
# [12. Level Order Tree Traversal](#trv12) <br>
# [13. Level order traversal in spiral form](#trv13) <br>
# [14. Level order traversal line by line](#trv14) <br>
# [15. Level order traversal with direction change after every two levels](#trv15) <br>
# [16. Reverse Level Order Traversal](#trv16) <br>
# [17. Reverse tree path](#trv17) <br>
# [18. Perfect Binary Tree Specific Level Order Traversal](#trv18) <br>
# [19. Perfect Binary Tree Specific Level Order Traversal | Set 2](#trv19) <br>
# [20. Reverse alternate levels of a perfect binary tree](#trv20) <br>
# [21. Morris traversal for Preorder](#trv21) <br>
# [22. Iterative Preorder Traversal](#trv22) <br>
# [23. Iterative Postorder Traversal | Set 1 (Using Two Stacks)](#trv23) <br>
# [24. Iterative Postorder Traversal | Set 2 (Using One Stack)](#trv24) <br>
# [25. Postorder traversal of Binary Tree without recursion and without stack](#trv25) <br>
# [26. Diagonal Traversal of Binary Tree](#trv26) <br>
# [27. Iterative diagonal traversal of binary tree](#trv27) <br>
# [28. Boundary Traversal of binary tree](#trv28) <br>
# [29. Density of Binary Tree in One Traversal](#trv29) <br>
# [30. Calculate depth of a full Binary tree from Preorder](#trv30) <br>
# [31. Number of Binary Trees for given Preorder Sequence length](#trv31) <br>
# [32. Modify a binary tree to get Preorder traversal using right pointers only](#trv32) <br>
# [33. vertical traversal](#trv33) <br>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='cac'></a>
# <h2 style="color:blue"> Construction and conversion </h2>
#
# [1. Construct Tree from given Inorder and Preorder traversals](#cac1) <br>
# [2. Construct a tree from Inorder and Level order traversals](#cac2) <br>
# [3. Construct Complete Binary Tree from its Linked List Representation](#cac3) <br>
# [4. Construct a complete binary tree from given array in level order fashion](#cac4) <br>
# [5. Construct Full Binary Tree from given preorder and postorder traversals](#cac5) <br>
# [6. Construct Full Binary Tree using its Preorder traversal and Preorder traversal of its mirror tree](#cac6) <br>
# [7. Construct a special tree from given preorder traversal](#cac7) <br>
# [8. Construct tree from ancestor matrix](#cac8) <br>
# [9. Construct Ancestor Matrix from a Given Binary Tree](#cac9) <br>
# [10. Construct Special Binary Tree from given Inorder traversal](#cac10) <br>
# [11. Construct Binary Tree from given Parent Array representation](#cac11) <br>
# [12. Construct a Binary Tree from Postorder and Inorder](#cac12) <br>
# [13. Create a Doubly Linked List from a Ternary Tree](#cac13) <br>
# [14. Creating a tree with Left-Child Right-Sibling Representation](#cac14) <br>
# [15. Prufer Code to Tree Creation](#cac15) <br>
# [16. If you are given two traversal sequences, can you construct the binary tree?](#cac16) <br>
# [17. Construct the full k-ary tree from its preorder traversal](#cac17) <br>
# [18. Construct Binary Tree from String with bracket representation](#cac18) <br>
# [19. Linked complete binary tree & its creation](#cac19) <br>
# [20. Convert a given Binary Tree to Doubly Linked List | Set 1](#cac20) <br>
# [21. Convert a given Binary Tree to Doubly Linked List | Set 2](#cac21) <br>
# [22. Convert a given Binary Tree to Doubly Linked List | Set 3](#cac22) <br>
# [23. Convert a given Binary Tree to Doubly Linked List | Set 4](#cac23) <br>
# [24. Convert an arbitrary Binary Tree to a tree that holds Children Sum Property](#cac24) <br>
# [25. Convert left-right representation of a binary tree to down-right](#cac25) <br>
# [26. Convert a given tree to its Sum Tree](#cac26) <br>
# [27. Change a Binary Tree so that every node stores sum of all nodes in left subtree](#cac27) <br>
# [28. Write an Efficient Function to Convert a Binary Tree into its Mirror Tree](#cac28) <br>
# [29. Convert a Binary Tree into Doubly Linked List in spiral fashion](#cac29) <br>
# [30. Convert a Binary Tree to a Circular Doubly Link List](#cac30) <br>
# [31. Convert a tree to forest of even nodes](#cac31) <br>
# [32. Convert a given Binary tree to a tree that holds Logical AND property](#cac32) <br>
# [33. Convert Ternary Expression to a Binary Tree](#cac33) <br>
# [34. Flip Binary Tree](#cac34) <br>
# [35. Minimum swap required to convert binary tree to binary search tree](#cac35) <br>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='cap'></a>
# <h2 style="color:blue"> Checking and printing </h2>
#
# [1. Check for Children Sum Property in a Binary Tree](#cap1) <br>
# [2. Check if a given Binary Tree is SumTree](#cap2) <br>
# [3. Check sum of Covered and Uncovered nodes of Binary Tree](#cap3) <br>
# [4. Check if two nodes are cousins in a Binary Tree](#cap4) <br>
# [5. Check if all leaves are at same level](#cap5) <br>
# [6. Check if removing an edge can divide a Binary Tree in two halves](#cap6) <br>
# [7. Check if given Preorder, Inorder and Postorder traversals are of same tree](#cap7) <br>
# [8. Given level order traversal of a Binary Tree, check if the Tree is a Min-Heap](#cap8) <br>
# [9. Check if leaf traversal of two Binary Trees is same?](#cap9) <br>
# [10. Check if a given Binary Tree is SumTree](#cap10) <br>
# [11. Check whether a given binary tree is perfect or not](#cap11) <br>
# [12. Check whether a binary tree is a full binary tree or not](#cap12) <br>
# [13. Check whether a binary tree is a full binary tree or not | Iterative Approach](#cap13) <br>
# [14. Check whether a given Binary Tree is Complete or not | Set 1 (Iterative Solution)](#cap14) <br>
# [15. Check if a given Binary Tree is height balanced like a Red-Black Tree](#cap15) <br>
# [16. Check if a binary tree is subtree of another binary tree | Set 2](#cap16) <br>
# [17. Check if a Binary Tree (not BST) has duplicate values](#cap17) <br>
# [18. Check if a Binary Tree contains duplicate subtrees of size 2 or more](#cap18) <br>
# [19. Check if a given graph is tree or not](#cap19) <br>
# [20. Check if two trees are Mirror](#cap20) <br>
# [21. Iterative method to check if two trees are mirror of each other](#cap21) <br>
# [22. Write Code to Determine if Two Trees are Identical](#cap22) <br>
# [23. Iterative function to check if two trees are identical](#cap23) <br>
# [24. Check for Symmetric Binary Tree (Iterative Approach)](#cap24) <br>
# [25. Check if there is a root to leaf path with given sequence](#cap25) <br>
# [26. Print middle level of perfect binary tree without finding height](#cap26) <br>
# [27. Print cousins of a given node in Binary Tree](#cap27) <br>
# [28. Given a binary tree, print out all of its root-to-leaf paths one per line](#cap28) <br>
# [29. Print the longest leaf to leaf path in a Binary tree.](#cap29) <br>
# [30. Print path from root to a given node in a binary tree](#cap30) <br>
# [31. Print root to leaf paths without using recursion](#cap31) <br>
# [32. Print all root to leaf paths with there relative positions](#cap32) <br>
# [33. Print the nodes at odd levels of a tree](#cap33) <br>
# [34. Print all full nodes in a Binary Tree](#cap34) <br>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='sum'></a>
# <h2 style="color:blue"> Summation </h2>
#
# [1. Sum of all nodes in a binary tree](#sum1) <br>
# [2. Sum of all the parent nodes having child node x](#sum2) <br>
# [3. Find sum of all left leaves in a given Binary Tree](#sum3) <br>
# [4. Find sum of all right leaves in a given Binary Tree](#sum4) <br>
# [5. Find sum of all nodes of the given perfect binary tree](#sum5) <br>
# [6. Diagonal Sum of a Binary Tree](#sum6) <br>
# [7. Find if there is a pair in root to a leaf path with sum equals to root’s data](#sum7) <br>
# [8. Sum of nodes on the longest path from root to leaf node](#sum8) <br>
# [9. Remove all nodes which don’t lie in any path with sum>= k](#sum9) <br>
# [10. Find the maximum path sum between two leaves of a binary tree](#sum10) <br>
# [11. Find the maximum sum leaf to root path in a Binary Tree](#sum11) <br>
# [12. Maximum sum of nodes in Binary tree such that no two are adjacent](#sum12) <br>
# [13. Maximum sum from a tree with adjacent levels not allowed](#sum13) <br>
# [14. Find largest subtree sum in a tree](#sum14) <br>
# [15. Print all k-sum paths in a binary tree](#sum15) <br>
# [16. Sum of heights of all individual nodes in a binary tree](#sum16) <br>
# [17. Subtree with given sum in a Binary Tree](#sum17) <br>
# [18. Count subtress that sum up to a given value x](#sum18) <br>
# [19. Sum of nodes at maximum depth of a Binary Tree](#sum19) <br>
# [20. Difference between sums of odd level and even level nodes of a Binary Tree](#sum20) <br>
# [21. Find maximum level sum in Binary Tree](#sum21) <br>
# [22. Maximum spiral sum in Binary Tree](#sum22) <br>
# [23. Sum of nodes at k-th level in a tree represented as string](#sum23) <br>
# [24. Sum of all leaf nodes of binary tree](#sum24) <br>
# [25. Sum of leaf nodes at minimum level](#sum25) <br>
# [26. Root to leaf path sum equal to a given number](#sum26) <br>
# [27. Sum of all the numbers that are formed from root to leaf paths](#sum27) <br>
# [28. Merge Two Binary Trees by doing Node Sum (Recursive and Iterative)](#sum28) <br>
# [29. Vertical Sum in a given Binary Tree | Set 1](#sum29) <br>
# [30. Vertical Sum in Binary Tree](#sum30) <br>
# [31. Find root of the tree where children id sum for every node is given](#sum31) <br>
# [32. Replace each node in binary tree with the sum of its inorder predecessor and successor](#sum32) <br>
# [33. Find largest subtree sum in a tree](#sum33) <br>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='lca'></a>
# <h2 style="color:blue"> Longest common ancestor </h2>
#
# [1. Lowest Common Ancestor in a Binary Tree | Set 1](#lca1) <br>
# [2. Lowest Common Ancestor in a Binary Tree | Set 2 (Using Parent Pointer)](#lca2) <br>
# [3. Lowest Common Ancestor in a Binary Tree | Set 3](#lca3) <br>
# [4. Find distance between two nodes of a Binary Tree](#lca4) <br>
# [5. Print common nodes on path from root (or common ancestors)](#lca5) <br>
# [6. Find LCA in Binary Tree using RMQ](#lca6) <br>
# [7. Maximum difference between node and its ancestor in Binary Tree](#lca7) <br>
# [8. Print the path common to the two paths from the root to the two given nodes](#lca8) <br>
# [9. Query for ancestor-descendant relationship in a tree](#lca9) <br>
# [10. Iterative method to find ancestors of a given binary tree](#lca10) <br>
# [11. Print Ancestors of a given node in Binary Tree](#lca11) <br>
# [12. Kth ancestor of a node in binary tree](#lca12) <br>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='mor'></a>
# <h2 style="color:blue"> More </h2>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='sol'></a>
# <h2 style="color:green"> Solutions </h2>
#
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='intrs'></a>
# <h2 style="color:green"> Introduction solutions </h2>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr1></a>
# <h3 style="color:gray">1. Binary Tree | Set 1 (Introduction) </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %%
from binarytree import build
nodes = [1,2,3]
root = build(nodes)
print(root)
# Out:
#   1
#  / \
# 2   3

# %% [markdown]
# <a id=intr2></a>
# <h3 style="color:gray">2. Binary Tree | Set 2 (Properties) </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr3></a>
# <h3 style="color:gray">3. Binary Tree | Set 3 (Types of Binary Tree) </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr4></a>
# <h3 style="color:gray">4. Handshaking Lemma and Interesting Tree Properties </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr5></a>
# <h3 style="color:gray">5. Enumeration of Binary Trees </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr6></a>
# <h3 style="color:gray">6. Insertion in a Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr7></a>
# <h3 style="color:gray">7. Deletion in a Binary Tree </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr8></a>
# <h3 style="color:gray">8. BFS vs DFS for Binary Tree </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr9></a>
# <h3 style="color:gray">9. Binary Tree (Array implementation) </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr10></a>
# <h3 style="color:gray">10. AVL with duplicate keys </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr11></a>
# <h3 style="color:gray">11. Applications of tree data structure </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr12></a>
# <h3 style="color:gray">12. Applications of Minimum Spanning Tree Problem </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr13></a>
# <h3 style="color:gray">13. Continuous Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr14></a>
# <h3 style="color:gray">14. Foldable Binary Trees </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr15></a>
# <h3 style="color:gray">15. Expression Tree </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr16></a>
# <h3 style="color:gray">16. Evaluation of Expression Tree </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=intr17></a>
# <h3 style="color:gray">17. Symmetric Tree (Mirror Image of itself) </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='trvs'></a>
# <h2 style="color:green"> Traversals solutions </h2>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv1></a>
# <h3 style="color:gray">1. Tree Traversals </h3>
# <blockquote style="background:#2E8B57; color:#F0F8FF; font-size:14x">
#  <h4>
#   Tree is a special kind of graph. There are two ways to traverse a graph -- breadth first and depth first.
#   All traversals of tree also fall under these two categories.
#   Level order traversal of tree is breadth first traversal. <br>
#   All depth first traversals of tree are-- Inorder, Preorder, Postorder
#  </h4>
# </blockquote>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv2></a>
# <h3 style="color:gray">2. Inorder Tree Traversal without Recursion </h3>
#
# <div class="alert alert-block alert-danger">
# <b>Danger:</b> This alert box indicates a dangerous or potentially negative action.
# </div>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv3></a>
# <h3 style="color:gray">3. Inorder Tree Traversal without recursion and without stack! </h3>
#
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.</div>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv4></a>
# <h3 style="color:gray">4. Print Postorder traversal from given Inorder and Preorder traversals </h3>
#
# ```java
# import java.util.*;
#
# public class Traversal1
# {
# 	public static int search(int arr[], int x, int n)
# 	{
# 		for(int i=0; i<n; i++)
# 		{
# 			if(arr[i] == x)
# 				return i;
# 		}
# 		return -1;
# 	}
# 	public static void postorderFromInorderAndPreorder(int in[], int pre[], int n)
# 	{
# 		int root = search(in, pre[0], n);
#
# 		if(root !=0 )
# 			postorderFromInorderAndPreorder(in, Arrays.copyOfRange(pre, 1, n), root);
# 		if(root != n-1)
# 			postorderFromInorderAndPreorder(Arrays.copyOfRange(in, root+1, n), Arrays.copyOfRange(pre, root+1, n), n-root-1);
#
# 		System.out.print(pre[0]);
# 	}
# 	public static void main(String a[])
# 	{
# 		int in[] = { 4, 2, 5, 1, 3, 6 };
#     	int pre[] = { 1, 2, 4, 5, 3, 6 };
#     	int n = in.length;
#     	postorderFromInorderAndPreorder(in, pre, n);
# 	}
# }
# ```
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv5></a>
# <h3 style="color:gray">5. Find postorder traversal of BST from preorder traversal </h3>
#
# <div class="alert alert-block alert-warning">
# <b>Example:</b> Use yellow boxes for examples that are not inside code cells, or use for mathematical formulas if needed. Typically also used to display warning messages.
# </div>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv6></a>
# <h3 style="color:gray">6. Find all possible binary trees with given Inorder Traversal </h3>
#
# <div class="alert alert-block alert-success">
# <b>Success:</b> This alert box indicates a successful or positive action.
# </div>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv7></a>
# <h3 style="color:gray">7. Replace each node in binary tree with the sum of its inorder predecessor and successor </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv8></a>
# <h3 style="color:gray">8. Populate Inorder Successor for all nodes </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv9></a>
# <h3 style="color:gray">9. Inorder Successor of a node in Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv10></a>
# <h3 style="color:gray">10. Find n-th node of inorder traversal </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv11></a>
# <h3 style="color:gray">11. Find n-th node in Postorder traversal of a Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv12></a>
# <h3 style="color:gray">12. Level Order Tree Traversal </h3>
#
# <blockquote style="background:#2E8B57; color:#F0F8FF; font-size:14x">
#  <h4>
#   Level order traversal is breadth first traversal of graph. Tree is a special graph. Queue ds is used in breadth first traversal.
#  </h4>
# </blockquote>
#
# ```java
# import java.util.*;
#
# class MyComparator implements Comparator
# {
# 	public int compare(Object o1, Object o2)
# 	{
# 		return 1;
# 	}
# }
#
# public class Traversal12
# {
# 	public static String levelOrderTraversal(BinaryTree t)
# 	{
# 		PriorityQueue q = new PriorityQueue(new MyComparator());
# 		TreeNode temp = t.root;
# 		String result = "";
# 		q.offer(temp);
#
# 		while(! q.isEmpty())
# 		{
# 			temp = (TreeNode)q.poll();
# 			result = result + temp.data.toString();
# 			if(temp.left != null)
# 				q.offer(temp.left);
# 			if(temp.right != null)
# 				q.offer(temp.right);
# 		}
# 		return result;
# 	}
# 	public static void main(String a[])
# 	{
# 		BinaryTree t = new BinaryTree();
# 	 	t.addNodes("[1 [2 [4 null null] [5 null null]] [3 null null]]");
# 	 	System.out.println(t.inorder());
#
# 	 	System.out.println(levelOrderTraversal(t));
# 	}
# }
# ```
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv13></a>
# <h3 style="color:gray">13. Level order traversal in spiral form </h3>
#
# ```java
# import java.util.*;
#
# public class Traversal13
# {
# 	public static String spiralTraversal(BinaryTree t)
# 	{
# 		TreeNode temp = t.root;
# 		Stack stack1 = new Stack();
# 		Stack stack2 = new Stack();
#
# 		String result = "";
#
# 		stack1.push(temp);
#
# 		while(! stack1.isEmpty() || ! stack2.isEmpty())
# 		{
# 			while(! stack1.isEmpty())
# 			{
# 				temp = (TreeNode)stack1.pop();
# 				result = result + temp.data.toString();
# 				if(temp.right != null)
# 					stack2.push(temp.right);
# 				if(temp.left != null)
# 					stack2.push(temp.left);
# 			}
# 			while(! stack2.isEmpty())
# 			{
# 				temp = (TreeNode)stack2.pop();
# 				result = result + temp.data.toString();
# 				if(temp.left != null)
# 					stack1.push(temp.left);
# 				if(temp.right != null)
# 					stack1.push(temp.right);
# 			}
# 		}
#
# 		return result;
# 	}
#
# 	public static void main(String a[])
# 	{
# 		BinaryTree t = new BinaryTree();
# 	 	t.addNodes("[1 [2 [4 null null] [5 null null]] [3 null null]]");
# 	 	t.root.right.addLeftRight(6,7);
# 	 	System.out.println(spiralTraversal(t));
# 	}
# }
# ```
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv14></a>
# <h3 style="color:gray">14. Level order traversal line by line </h3>
#
# ```java
# import java.util.*;
#
# public class Traversal14
# {
# 	public static String levelOrderTraversalByLine(BinaryTree t)
# 	{
# 		LinkedList list = new LinkedList();
# 		TreeNode temp = t.root;
# 		String result = "";
# 		Object obj = null;
# 		list.addLast(temp);
# 		list.addLast("\n");
#
# 		while(list.size() > 1)
# 		{
# 			obj = list.getFirst();
# 			list.removeFirst();
# 			if(obj instanceof String)
# 			{
# 				result = result + "\n";
# 				list.addLast("\n");
# 				continue;
# 			}
#
# 			temp = (TreeNode)obj;
# 			result = result + temp.data.toString();
# 			if(temp.left != null)
# 			{
# 				list.addLast(temp.left);
# 			}
# 			if(temp.right != null)
# 			{
# 				list.addLast(temp.right);
# 			}
# 		}
# 		return result;
# 	}
# 	public static void main(String a[])
# 	{
# 		BinaryTree t = new BinaryTree();
# 	 	t.addNodes("[1 [2 [4 null null] [5 null null]] [3 null null]]");
# 	 	System.out.println(t.inorder());
#
# 	 	System.out.println(levelOrderTraversalByLine(t));
# 	}
# }
# ```
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv15></a>
# <h3 style="color:gray">15. Level order traversal with direction change after every two levels </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv16></a>
# <h3 style="color:gray">16. Reverse Level Order Traversal </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv17></a>
# <h3 style="color:gray">17. Reverse tree path </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv18></a>
# <h3 style="color:gray">18. Perfect Binary Tree Specific Level Order Traversal </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv19></a>
# <h3 style="color:gray">19. Perfect Binary Tree Specific Level Order Traversal | Set 2 </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv20></a>
# <h3 style="color:gray">20. Reverse alternate levels of a perfect binary tree </h3>
#
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv21></a>
# <h3 style="color:gray">21. Morris traversal for Preorder </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv22></a>
# <h3 style="color:gray">22. Iterative Preorder Traversal </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv23></a>
# <h3 style="color:gray">23. Iterative Postorder Traversal | Set 1 (Using Two Stacks) </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv24></a>
# <h3 style="color:gray">24. Iterative Postorder Traversal | Set 2 (Using One Stack) </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv25></a>
# <h3 style="color:gray">25. Postorder traversal of Binary Tree without recursion and without stack </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv26></a>
# <h3 style="color:gray">26. Diagonal Traversal of Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv27></a>
# <h3 style="color:gray">27. Iterative diagonal traversal of binary tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv28></a>
# <h3 style="color:gray">28. Boundary Traversal of binary tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv29></a>
# <h3 style="color:gray">29. Density of Binary Tree in One Traversal </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv30></a>
# <h3 style="color:gray">30. Calculate depth of a full Binary tree from Preorder </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv31></a>
# <h3 style="color:gray">31. Number of Binary Trees for given Preorder Sequence length </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv32></a>
# <h3 style="color:gray">32. Modify a binary tree to get Preorder traversal using right pointers only </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=trv33></a>
# <h3 style="color:gray">33. vertical traversal </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='cacs'></a>
# <h2 style="color:green"> construction and conversion solutions </h2>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac1></a>
# <h3 style="color:gray">1. Construct Tree from given Inorder and Preorder traversals </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac2></a>
# <h3 style="color:gray">2. Construct a tree from Inorder and Level order traversals </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac3></a>
# <h3 style="color:gray">3. Construct Complete Binary Tree from its Linked List Representation </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac4></a>
# <h3 style="color:gray">4. Construct a complete binary tree from given array in level order fashion </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac5></a>
# <h3 style="color:gray">5. Construct Full Binary Tree from given preorder and postorder traversals </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac6></a>
# <h3 style="color:gray">6. Construct Full Binary Tree using its Preorder traversal and Preorder traversal of its mirror tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac7></a>
# <h3 style="color:gray">7. Construct a special tree from given preorder traversal </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac8></a>
# <h3 style="color:gray">8. Construct tree from ancestor matrix </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac9></a>
# <h3 style="color:gray">9. Construct Ancestor Matrix from a Given Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac10></a>
# <h3 style="color:gray">10. Construct Special Binary Tree from given Inorder traversal </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac11></a>
# <h3 style="color:gray">11. Construct Binary Tree from given Parent Array representation </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac12></a>
# <h3 style="color:gray">12. Construct a Binary Tree from Postorder and Inorder </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac13></a>
# <h3 style="color:gray">13. Create a Doubly Linked List from a Ternary Tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac14></a>
# <h3 style="color:gray">14. Creating a tree with Left-Child Right-Sibling Representation </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac15></a>
# <h3 style="color:gray">15. Prufer Code to Tree Creation </h3>
#
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac16></a>
# <h3 style="color:gray">16. If you are given two traversal sequences, can you construct the binary tree? </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac17></a>
# <h3 style="color:gray">17. Construct the full k-ary tree from its preorder traversal </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac18></a>
# <h3 style="color:gray">18. Construct Binary Tree from String with bracket representation </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac19></a>
# <h3 style="color:gray">19. Linked complete binary tree & its creation </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac20></a>
# <h3 style="color:gray">20. Convert a given Binary Tree to Doubly Linked List | Set 1 </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac21></a>
# <h3 style="color:gray">21. Convert a given Binary Tree to Doubly Linked List | Set 2 </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac22></a>
# <h3 style="color:gray">22. Convert a given Binary Tree to Doubly Linked List | Set 3 </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac23></a>
# <h3 style="color:gray">23. Convert a given Binary Tree to Doubly Linked List | Set 4 </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac24></a>
# <h3 style="color:gray">24. Convert an arbitrary Binary Tree to a tree that holds Children Sum Property </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac25></a>
# <h3 style="color:gray">25. Convert left-right representation of a binary tree to down-right </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac26></a>
# <h3 style="color:gray">26. Convert a given tree to its Sum Tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac27></a>
# <h3 style="color:gray">27. Change a Binary Tree so that every node stores sum of all nodes in left subtree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac28></a>
# <h3 style="color:gray">28. Write an Efficient Function to Convert a Binary Tree into its Mirror Tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac29></a>
# <h3 style="color:gray">29. Convert a Binary Tree into Doubly Linked List in spiral fashion </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac30></a>
# <h3 style="color:gray">30. Convert a Binary Tree to a Circular Doubly Link List </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac31></a>
# <h3 style="color:gray">31. Convert a tree to forest of even nodes </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac32></a>
# <h3 style="color:gray">32. Convert a given Binary tree to a tree that holds Logical AND property </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac33></a>
# <h3 style="color:gray">33. Convert Ternary Expression to a Binary Tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac34></a>
# <h3 style="color:gray">34. Flip Binary Tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cac35></a>
# <h3 style="color:gray">35. Minimum swap required to convert binary tree to binary search tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='caps'></a>
# <h2 style="color:green"> checking and printing solutions </h2>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap1></a>
# <h3 style="color:gray">1. Check for Children Sum Property in a Binary Tree </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap2></a>
# <h3 style="color:gray">2. Check if a given Binary Tree is SumTree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap3></a>
# <h3 style="color:gray">3. Check sum of Covered and Uncovered nodes of Binary Tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap4></a>
# <h3 style="color:gray">4. Check if two nodes are cousins in a Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap5></a>
# <h3 style="color:gray">5. Check if all leaves are at same level </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap6></a>
# <h3 style="color:gray">6. Check if removing an edge can divide a Binary Tree in two halves </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap7></a>
# <h3 style="color:gray">7. Check if given Preorder, Inorder and Postorder traversals are of same tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap8></a>
# <h3 style="color:gray">8. Given level order traversal of a Binary Tree, check if the Tree is a Min-Heap </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# a id=cap9></a>
# <h3 style="color:gray">9. Check if leaf traversal of two Binary Trees is same? </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap10></a>
# <h3 style="color:gray">10. Check if a given Binary Tree is SumTree </h3>
#
# <blockquote style="background:#2E8B57; color:#F0F8FF; font-size:14x">
#  <h4>
#      A tree is sum tree if every node in tree contains value equals to sum of values of its left, right nodes.
#      Approach : Traverse the tree in postorder.
#  </h4>
# </blockquote>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap11></a>
# <h3 style="color:gray">11. Check whether a given binary tree is perfect or not </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap12></a>
# <h3 style="color:gray">12. Check whether a binary tree is a full binary tree or not </h3>
#
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap13></a>
# <h3 style="color:gray">13. Check whether a binary tree is a full binary tree or not | Iterative Approach </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap14></a>
# <h3 style="color:gray">14. Check whether a given Binary Tree is Complete or not | Set 1 (Iterative Solution) </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap15></a>
# <h3 style="color:gray">15. Check if a given Binary Tree is height balanced like a Red-Black Tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap16></a>
# <h3 style="color:gray">16. Check if a binary tree is subtree of another binary tree | Set 2 </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap17></a>
# <h3 style="color:gray">17. Check if a Binary Tree (not BST) has duplicate values </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap18></a>
# <h3 style="color:gray">18. Check if a Binary Tree contains duplicate subtrees of size 2 or more </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap19></a>
# <h3 style="color:gray">19. Check if a given graph is tree or not </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap20></a>
# <h3 style="color:gray">20. Check if two trees are Mirror </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap21></a>
# <h3 style="color:gray">21. Iterative method to check if two trees are mirror of each other </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap22></a>
# <h3 style="color:gray">22. Write Code to Determine if Two Trees are Identical </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap23></a>
# <h3 style="color:gray">23. Iterative function to check if two trees are identical </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap24></a>
# <h3 style="color:gray">24. Check for Symmetric Binary Tree (Iterative Approach) </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap25></a>
# <h3 style="color:gray">25. Check if there is a root to leaf path with given sequence </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap26></a>
# <h3 style="color:gray">26. Print middle level of perfect binary tree without finding height </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap27></a>
# <h3 style="color:gray">27. Print cousins of a given node in Binary Tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap28></a>
# <h3 style="color:gray">28. Given a binary tree, print out all of its root-to-leaf paths one per line </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap29></a>
# <h3 style="color:gray">29. Print the longest leaf to leaf path in a Binary tree. </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap30></a>
# <h3 style="color:gray">30. Print path from root to a given node in a binary tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap31></a>
# <h3 style="color:gray">31. Print root to leaf paths without using recursion </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap32></a>
# <h3 style="color:gray">32. Print all root to leaf paths with there relative positions </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap33></a>
# <h3 style="color:gray">33. Print the nodes at odd levels of a tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=cap34></a>
# <h3 style="color:gray">34. Print all full nodes in a Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='sums'></a>
# <h2 style="color:green"> Summation solutions </h2>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum1></a>
# <h3 style="color:gray">1. Sum of all nodes in a binary tree </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum2></a>
# <h3 style="color:gray">2. Sum of all the parent nodes having child node x </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum3></a>
# <h3 style="color:gray">3. Find sum of all left leaves in a given Binary Tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum4></a>
# <h3 style="color:gray">4. Find sum of all right leaves in a given Binary Tree </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum5></a>
# <h3 style="color:gray">5. Find sum of all nodes of the given perfect binary tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum6></a>
# <h3 style="color:gray">6. Diagonal Sum of a Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum7></a>
# <h3 style="color:gray">7. Find if there is a pair in root to a leaf path with sum equals to root’s data </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum8></a>
# <h3 style="color:gray">8. Sum of nodes on the longest path from root to leaf node </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum9></a>
# <h3 style="color:gray">9. Remove all nodes which don’t lie in any path with sum>= k </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum10></a>
# <h3 style="color:gray">10. Find the maximum path sum between two leaves of a binary tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum11></a>
# <h3 style="color:gray">11. Find the maximum sum leaf to root path in a Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum12></a>
# <h3 style="color:gray">12. Maximum sum of nodes in Binary tree such that no two are adjacent </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum13></a>
# <h3 style="color:gray">13. Maximum sum from a tree with adjacent levels not allowed </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum14></a>
# <h3 style="color:gray">14. Find largest subtree sum in a tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum15></a>
# <h3 style="color:gray">15. Print all k-sum paths in a binary tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum16></a>
# <h3 style="color:gray">16. Sum of heights of all individual nodes in a binary tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum17></a>
# <h3 style="color:gray">17. Subtree with given sum in a Binary Tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum18></a>
# <h3 style="color:gray">18. Count subtress that sum up to a given value x </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum19></a>
# <h3 style="color:gray">19. Sum of nodes at maximum depth of a Binary Tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum20></a>
# <h3 style="color:gray">20. Difference between sums of odd level and even level nodes of a Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum21></a>
# <h3 style="color:gray">21. Find maximum level sum in Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum22></a>
# <h3 style="color:gray">22. Maximum spiral sum in Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum23></a>
# <h3 style="color:gray">23. Sum of nodes at k-th level in a tree represented as string </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum24></a>
# <h3 style="color:gray">24. Sum of all leaf nodes of binary tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum25></a>
# <h3 style="color:gray">25. Sum of leaf nodes at minimum level </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum26></a>
# <h3 style="color:gray">26. Root to leaf path sum equal to a given number </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum27></a>
# <h3 style="color:gray">27. Sum of all the numbers that are formed from root to leaf paths </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum28></a>
# <h3 style="color:gray">28. Merge Two Binary Trees by doing Node Sum (Recursive and Iterative) </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum29></a>
# <h3 style="color:gray">29. Vertical Sum in a given Binary Tree | Set 1 </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum30></a>
# <h3 style="color:gray">30. Vertical Sum in Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum31></a>
# <h3 style="color:gray">31. Find root of the tree where children id sum for every node is given </h3>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum32></a>
# <h3 style="color:gray">32. Replace each node in binary tree with the sum of its inorder predecessor and successor </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=sum33></a>
# <h3 style="color:gray">33. Find largest subtree sum in a tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id='lcas'></a>
# <h2 style="color:green"> Longest common ancestor solutions </h2>
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca1></a>
# <h3 style="color:gray">1. Lowest Common Ancestor in a Binary Tree | Set 1 </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca2></a>
# <h3 style="color:gray">2. Lowest Common Ancestor in a Binary Tree | Set 2 (Using Parent Pointer) </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca3></a>
# <h3 style="color:gray">3. Lowest Common Ancestor in a Binary Tree | Set 3 </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca4></a>
# <h3 style="color:gray">4. Find distance between two nodes of a Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca5></a>
# <h3 style="color:gray">5. Print common nodes on path from root (or common ancestors) </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca6></a>
# <h3 style="color:gray">6. Find LCA in Binary Tree using RMQ </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca7></a>
# <h3 style="color:gray">7. Maximum difference between node and its ancestor in Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca8></a>
# <h3 style="color:gray">8. Print the path common to the two paths from the root to the two given nodes </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca9></a>
# <h3 style="color:gray">9. Query for ancestor-descendant relationship in a tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca10></a>
# <h3 style="color:gray">10. Iterative method to find ancestors of a given binary tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca11></a>
# <h3 style="color:gray">11. Print Ancestors of a given node in Binary Tree </h3>
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)

# %% [markdown]
# <a id=lca12></a>
# <h3 style="color:gray">12. Kth ancestor of a node in binary tree </h3>
#
#
#
# Questions:
# [Introduction](#intr)
# [Traversal](#trv)
# [CAC](#cac)
# [CAP](#cap)
# [Summation](#sum)
# [LCA](#lca)
# Solutions:
# [Introduction](#intrs)
# [Traversal](#trvs)
# [CAC](#cacs)
# [CAP](#caps)
# [Summation](#sums)
# [LCA](#lcas)
